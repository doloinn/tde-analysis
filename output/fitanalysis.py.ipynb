# %%
import pandas as pd
import numpy as np
import pandas_profiling

# %%
fitdf = pd.read_csv('fittdes.csv', index_col=0)

# %%
# pandas_profiling.ProfileReport(fitdf.loc[fitdf['gal rad'] == 5].loc[fitdf['gal mag'] == 20])
pandas_profiling.ProfileReport(fitdf.loc[fitdf['cadence'] == 15])
# Out:
# /Users/david/anaconda/lib/python3.5/site-packages/pandas_profiling/base.py:133: MatplotlibDeprecationWarning: The set_axis_bgcolor function was deprecated in version 2.0. Use set_facecolor instead.
#   plot.set_axis_bgcolor("w")
# /Users/david/anaconda/lib/python3.5/site-packages/pandas_profiling/base.py:133: MatplotlibDeprecationWarning: The set_axis_bgcolor function was deprecated in version 2.0. Use set_facecolor instead.
#   plot.set_axis_bgcolor("w")
# /Users/david/anaconda/lib/python3.5/site-packages/pandas_profiling/base.py:133: MatplotlibDeprecationWarning: The set_axis_bgcolor function was deprecated in version 2.0. Use set_facecolor instead.
#   plot.set_axis_bgcolor("w")
# /Users/david/anaconda/lib/python3.5/site-packages/pandas_profiling/base.py:133: MatplotlibDeprecationWarning: The set_axis_bgcolor function was deprecated in version 2.0. Use set_facecolor instead.
#   plot.set_axis_bgcolor("w")
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
# ...
